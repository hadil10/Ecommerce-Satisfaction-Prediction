# %%
import sys
# !{sys.executable} -m pip install pandas matplotlib seaborn
print("✅ Installation terminée avec succès !")
# Out:
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
#   Using cached contourpy-1.3.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.63.0-cp312-cp312-win_amd64.whl.metadata (121 kB)
# ...
#   Using cached kiwisolver-1.5.0-cp312-cp312-win_amd64.whl.metadata (5.2 kB)
# ...
#   Using cached pillow-12.2.0-cp312-cp312-win_amd64.whl.metadata (9.0 kB)
# ...
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# ...
#    ---------------------------------------- 0.0/9.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.3 MB 3.4 MB/s eta 0:00:03
#    ----- ---------------------------------- 1.3/9.3 MB 3.5 MB/s eta 0:00:03
#    -------- ------------------------------- 2.1/9.3 MB 3.6 MB/s eta 0:00:03
#    ----------- ---------------------------- 2.6/9.3 MB 3.4 MB/s eta 0:00:02
#    ------------- -------------------------- 3.1/9.3 MB 3.2 MB/s eta 0:00:02
# ...

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print("Génération du graphique amélioré...")

# Configuration du style visuel
sns.set_theme(style="whitegrid")

# Création de la figure (un peu plus large pour laisser la place au texte)
plt.figure(figsize=(10, 6))

# Création du graphique
sns.countplot(data=df_master, x='review_score', palette='viridis')

# Ajout des titres et labels
plt.title('Répartition des notes de satisfaction client', fontsize=14, fontweight='bold')
plt.xlabel('Niveau de satisfaction', fontsize=12)
plt.ylabel('Nombre de commandes', fontsize=12)

# NOUVEAU : Remplacement des numéros par du texte clair
noms_barres = ['1 étoile\n(Très déçu)', '2 étoiles', '3 étoiles', '4 étoiles', '5 étoiles\n(Parfait)']
plt.xticks(ticks=[0, 1, 2, 3, 4], labels=noms_barres)

# Affichage du graphique
plt.show()
# Out:
# Génération du graphique amélioré...
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11940\2815616448.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_master, x='review_score', palette='viridis')

# %%
print("Le moteur est réveillé !")
# Out:
# Le moteur est réveillé !

# %%
print("Analyse de l'impact des retards...")

plt.figure(figsize=(8, 5))

# Création du graphique
sns.barplot(data=df_master, x='retard_livraison', y='review_score', palette='coolwarm')

# Ajout des titres et labels
plt.title('Impact du retard de livraison sur la satisfaction', fontsize=14, fontweight='bold')
plt.xlabel('Statut de la livraison', fontsize=12)
plt.ylabel('Note moyenne (sur 5)', fontsize=12)
plt.ylim(1, 5)

# NOUVEAU : Remplacement des 0 et 1 par du texte clair
plt.xticks(ticks=[0, 1], labels=['À l\'heure\n(ou en avance)', 'En retard'])

plt.show()
# Out:
# Analyse de l'impact des retards...
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_11940\2368001155.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_master, x='retard_livraison', y='review_score', palette='coolwarm')
